# %%
import pandas as pd
df= pd.read_csv('carprices.csv')
df.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Mileage'], df['Sell Price($)'])

# %%
plt.scatter(df['Age(yrs)'], df['Sell Price($)'])

# %%
X =df[['Mileage', 'Age(yrs)']]
Y =df['Sell Price($)']
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    79000         7
# 11    83000         7
# 12    58870         4
# 13    82450         3
# 14    59000         5
# 15    52000         2
# 16    71000         5
# 17    87600         8
# 18    52000         5

# %%
Y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    27500
# 13    19400
# 14    23000
# 15    35500
# 16    19700
# 17    12800
# 18    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size= 0.2)

len(X_train)
len(X_test)
# Out:
# 4

# %%
from sklearn.linear_model import LinearRegression
clf =LinearRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([11848.09097363, 15636.43494122, 21371.28966132, 31218.90680776])

# %%
Y_test
# Out:
# 8     12000
# 11    19500
# 0     18000
# 4     31500
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test,Y_test)
# Out:
# 0.8681906682698574
